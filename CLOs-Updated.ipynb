# %%
# !pip install pandas
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.22.4 in ./.local/lib/python3.9/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in ./.local/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in ./.local/lib/python3.9/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.local/lib/python3.9/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.local/lib/python3.9/site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.8.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd

# New filenames
b530 = pd.read_csv('b530_updated.csv')
b505 = pd.read_csv('b505_updated.csv')
i501 = pd.read_csv('i501_updated.csv')
b535 = pd.read_csv('b535_updated.csv')
b518 = pd.read_csv('b518_updated.csv')
b581 = pd.read_csv('b581_updated.csv')
b642 = pd.read_csv('b642_updated.csv')

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # b530

# %%
b530.head()
# Out:
#                       STUDENT_IDS  CLO1   CLO2  CLO3  CLO4   CLO5  CLO6  \
# 0                         CLO_MAX  40.0  195.0  48.0  76.0  108.0  90.0
# 1  FA20-INFO-B 530 - 0100 (24447)  35.1  170.5  42.2  66.5   94.9  80.0
# 2  FA20-INFO-B 530 - 0100 (24447)  35.0  171.5  42.7  64.9   94.9  76.4
# 3  FA20-INFO-B 530 - 0100 (24447)  34.7  166.2  41.0  67.2   93.1  79.4
# 4  FA20-INFO-B 530 - 0100 (24447)  33.3  169.0  40.1  62.9   89.3  77.5
#
#     CLO7  Final_grade
# 0  100.0       100.00
# 1   90.0        90.89
# 2   88.3        89.27
# 3   85.4        88.48
# 4   83.3        86.98

# %%
import matplotlib as plt
import seaborn as sns

# %%
b530dropped=b530.drop('STUDENT_IDS', axis=1)

# %%
b530_CL01 = b530['CLO1']
b530_CL02 = b530['CLO2']
b530_CL03 = b530['CLO3']
b530_CL04 = b530['CLO4']
b530_CL05 = b530['CLO5']
b530_CL06 = b530['CLO6']
b530_CL07 = b530['CLO7']

# %%
b530_CL01 = b530_CL01.iloc[1:]

# Calculate the percentage of students who secured above 80%
above_80_b530_CL01 = (b530_CL01 > 32).sum() / len(b530_CL01) * 100

# Print the result
print(f"{above_80_b530_CL01:.2f}% of students secured above 80% in the b530_CL01.")
# Out:
# 96.18% of students secured above 80% in the b530_CL01.

# %%
b530_CL02 = b530_CL02.iloc[1:]

# Calculate the percentage of students who secured above 80%
above_80_b530_CL02 = (b530_CL02 > 156).sum() / len(b530_CL02) * 100

# Print the result
print(f"{above_80_b530_CL02:.2f}% of students secured above 80% in the b530_CL02.")
# Out:
# 97.33% of students secured above 80% in the b530_CL02.

# %%
b530_CL03 = b530_CL03.iloc[1:]
above_80_b530_CL03 = (b530_CL03 > 38.4).sum() / len(b530_CL03) * 100
print(f"{above_80_b530_CL03:.2f}% of students secured above 80% in the b530_CL03.")

b530_CL04 = b530_CL04.iloc[1:]
above_80_b530_CL04 = (b530_CL04 > 60.8).sum() / len(b530_CL04) * 100
print(f"{above_80_b530_CL04:.2f}% of students secured above 80% in the b530_CL04.")

b530_CL05 = b530_CL05.iloc[1:]
above_80_b530_CL05 = (b530_CL05 > 86.4).sum() / len(b530_CL05) * 100
print(f"{above_80_b530_CL05:.2f}% of students secured above 80% in the b530_CL05.")

b530_CL06 = b530_CL06.iloc[1:]
above_80_b530_CL06 = (b530_CL06 > 72).sum() / len(b530_CL06) * 100
print(f"{above_80_b530_CL06:.2f}% of students secured above 80% in the b530_CL06.")

b530_CL07 = b530_CL07.iloc[1:]
above_80_b530_CL07 = (b530_CL07 > 80).sum() / len(b530_CL07) * 100
print(f"{above_80_b530_CL07:.2f}% of students secured above 80% in the b530_CL07.")
# Out:
# 96.18% of students secured above 80% in the b530_CL03.
# 97.90% of students secured above 80% in the b530_CL04.
# 98.09% of students secured above 80% in the b530_CL05.
# 97.52% of students secured above 80% in the b530_CL06.
# 98.28% of students secured above 80% in the b530_CL07.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in ./.local/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.9/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: numpy>=1.23 in ./.local/lib/python3.9/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.9/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.hist(b530_CL01, 10)
# Out:
# (array([  1.,   0.,   1.,   0.,   6.,  21., 129., 225., 112.,  29.]),
#  array([21.8 , 23.61, 25.42, 27.23, 29.04, 30.85, 32.66, 34.47, 36.28,
#         38.09, 39.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b530_CL02, 5)
# Out:
# (array([  1.,   2.,  42., 401.,  78.]),
#  array([107.2, 125.3, 143.4, 161.5, 179.6, 197.7]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(b530_CL03, 10)
# Out:
# (array([  1.,   0.,   0.,   1.,   3.,  20., 132., 240., 102.,  25.]),
#  array([24.3 , 26.73, 29.16, 31.59, 34.02, 36.45, 38.88, 41.31, 43.74,
#         46.17, 48.6 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b530_CL04, 10)
# Out:
# (array([  1.,   0.,   0.,   1.,   3.,   5.,  83., 239., 164.,  28.]),
#  array([36.7 , 40.62, 44.54, 48.46, 52.38, 56.3 , 60.22, 64.14, 68.06,
#         71.98, 75.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b530_CL05, 10)
# Out:
# (array([  1.,   0.,   0.,   2.,   1.,  13., 174., 242.,  82.,   9.]),
#  array([ 54.5 ,  60.09,  65.68,  71.27,  76.86,  82.45,  88.04,  93.63,
#          99.22, 104.81, 110.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b530_CL06, 10)
# Out:
# (array([  1.,   0.,   0.,   2.,   2.,  24., 202., 231.,  57.,   5.]),
#  array([45.6 , 50.36, 55.12, 59.88, 64.64, 69.4 , 74.16, 78.92, 83.68,
#         88.44, 93.2 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b530_CL07, 10)
# Out:
# (array([  1.,   0.,   0.,   2.,   2.,   5., 115., 229., 141.,  29.]),
#  array([51.6 , 56.42, 61.24, 66.06, 70.88, 75.7 , 80.52, 85.34, 90.16,
#         94.98, 99.8 ]),
#  <BarContainer object of 10 artists>)

# %%
b530
# Out:
#                         STUDENT_IDS  CLO1   CLO2  CLO3  CLO4   CLO5  CLO6  \
# 0                           CLO_MAX  40.0  195.0  48.0  76.0  108.0  90.0
# 1    FA20-INFO-B 530 - 0100 (24447)  35.1  170.5  42.2  66.5   94.9  80.0
# 2    FA20-INFO-B 530 - 0100 (24447)  35.0  171.5  42.7  64.9   94.9  76.4
# 3    FA20-INFO-B 530 - 0100 (24447)  34.7  166.2  41.0  67.2   93.1  79.4
# 4    FA20-INFO-B 530 - 0100 (24447)  33.3  169.0  40.1  62.9   89.3  77.5
# ..                              ...   ...    ...   ...   ...    ...   ...
# 520         FA23-IN-INFO-B530-29026  34.8  173.1  42.4  68.9   96.4  81.6
# 521         FA23-IN-INFO-B530-29026  36.9  181.6  43.6  65.0   98.3  81.4
# 522         FA23-IN-INFO-B530-29026  37.0  177.0  45.2  74.5  101.0  81.8
# 523         FA23-IN-INFO-B530-29026  34.8  182.4  45.7  71.4  105.7  81.5
# 524         FA23-IN-INFO-B530-29026  36.9  185.9  46.7  71.7  102.9  79.7
#
#       CLO7  Final_grade
# 0    100.0       100.00
# 1     90.0        90.89
# 2     88.3        89.27
# 3     85.4        88.48
# 4     83.3        86.98
# ..     ...          ...
# 520   91.7        89.63
# 521   89.7        90.77
# 522   95.8        93.18
# 523   96.0        93.98
# 524   93.0        93.87
#
# [525 rows x 9 columns]

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']
histb530 = b530[columns].values
plt.hist(histb530.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

barb530 = b530[columns].values
plt.bar(range(len(columns)), barb530.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-530 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('530barcblue.png') 
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

# Calculate the mean values for each column
means = b530[columns].mean()

# Plot the bar chart
plt.bar(range(len(columns)), means, color='#B0E0E6')

# Add the density line
sns.kdeplot(data=b530[columns], color='red')

# Set the labels and title
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('Bar Chart with Density')

# Set the x-axis tick labels
plt.xticks(range(len(columns)), columns, rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

# Calculate the mean values and standard deviations for each column
means = b530[columns].mean()
stds = b530[columns].std()

# Plot the bar chart with error bars
plt.bar(range(len(columns)), means, yerr=stds, color='#B0E0E6', capsize=5)

# Set the labels and title
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('Bar Chart with Error Bars')

# Set the x-axis tick labels
plt.xticks(range(len(columns)), columns, rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

# Create a single subplot for all columns
fig, ax = plt.subplots(figsize=(12, 6))

# Define a color palette for the CLO columns
colors = ['darkblue', 'darkgreen', 'darkorange', 'purple', 'teal', 'maroon', 'navy']

# Iterate over columns and create bar charts with density lines
for i, col in enumerate(columns):
    sns.histplot(data=b530[col], ax=ax, element="bars", fill=True, color=colors[i], stat="density", alpha=0.7, label=col)
    sns.kdeplot(data=b530[col], ax=ax, color=colors[i], linewidth=2)

# Set the labels and title
ax.set_xlabel('Values')
ax.set_ylabel('Density')
ax.set_title('Bar Chart with Density')

# Set the x-axis tick labels
# ax.set_xticks(range(len(columns)))
# ax.set_xticklabels(columns, rotation=45)

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

# Concatenate the data from all columns into a single array
combined_data = np.concatenate([b530[col].values for col in columns])

# Create a single subplot for the combined histogram
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the combined histogram with density line
sns.histplot(data=combined_data, ax=ax, element="bars", fill=True, color='darkblue', stat="density", alpha=0.7)

# Plot the KDE line
sns.kdeplot(data=combined_data, ax=ax, color='red', linewidth=2)

# Set the labels and title
ax.set_xlabel('Values')
ax.set_ylabel('Density')
ax.set_title('Combined Histogram with Density')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'b530' with the desired data in the 7 columns
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

# Create a single plot for all columns
fig, ax = plt.subplots(figsize=(8, 6))

# Iterate over columns and create histograms with density lines
for col in columns:
    sns.histplot(data=b530[col], ax=ax, discrete=True,
                 color='darkblue', edgecolor='black',
                 kde=True, kde_kws={'cut': 2}, line_kws={'linewidth': 2})

# Set x-axis label, y-axis label, and title
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Histograms with Density')

# Set legend
ax.legend(columns)

# Show the plot
plt.show()

# %%
import seaborn as sns

# Extract the values for CLO1-CLO7 from the b530 DataFrame
barb530 = b530[columns]

# Create a density plot using seaborn
sns.kdeplot(data=barb530)

# Set the labels and title
plt.xlabel('Class Learning Objectives')
plt.ylabel('Density')
plt.title('Density Plot')

# Set the x-axis tick labels
# plt.xticks(range(len(columns)), columns, rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# Save the plot as an image file
plt.savefig('530densityplot.png')

# %%
import seaborn as sns

# Extract the values for CLO1-CLO7 from the b530 DataFrame
barb530 = b530[columns]

# Create a density plot using seaborn
sns.set(style="whitegrid")
for column in columns:
    sns.kdeplot(data=barb530[column], label=column, shade=True, linewidth=2)

# Set the labels and title
plt.xlabel('Class Learning Objectives', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.title('B530 Density Plot', fontsize=14)

# Set the x-axis tick labels
# plt.xticks(range(len(columns)), columns, rotation=45, fontsize=10)

# Set the y-axis tick labels
plt.yticks(fontsize=10)

# Add a legend
plt.legend(title='Courses', fontsize=10)

# Adjust the plot layout
plt.tight_layout()

# Display the plot
plt.show()

# Save the plot as an image file
plt.savefig('530densityplot.png', dpi=300)

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b530['grade'] = pd.cut(b530['Final_grade'], bins, labels=labels)

# %%
b530 = b530.drop(['STUDENT_IDS'], axis = 1)
# b530 = b530.drop(['Final_grade'], axis = 1)
b530 = b530.drop (0, axis = 0)
b530.head()
# Out:
#    CLO1   CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  Final_grade grade
# 1  35.1  170.5  42.2  66.5  94.9  80.0  90.0        90.89    A-
# 2  35.0  171.5  42.7  64.9  94.9  76.4  88.3        89.27    B+
# 3  34.7  166.2  41.0  67.2  93.1  79.4  85.4        88.48    B+
# 4  33.3  169.0  40.1  62.9  89.3  77.5  83.3        86.98     B
# 5  34.5  166.4  40.3  66.6  94.9  76.4  84.2        87.99    B+

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(38, 16))
sns.heatmap(b530dropped.corr(), annot=True)
sns.set(font_scale=5)

plt.show()

# %%
# convert to numerical
b530 = b530.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int',"CLO7":'int'})

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in ./.local/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.local/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in ./.local/lib/python3.9/site-packages (from scikit-learn) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in ./.local/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.local/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Missing values in your DataFrame
missing_values = b530.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# CLO7           0
# Final_grade    0
# grade          6
# dtype: int64

# %%
missing_values = b530[b530['grade'].isnull()]
print(missing_values)
# Out:
#      CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  Final_grade grade
# 361    32   145    36    57    83    68    78        76.36   NaN
# 398    29   136    34    56    74    63    70        70.73   NaN
# 424    30   147    36    58    79    67    72        74.87   NaN
# 436    21   107    24    36    54    45    51        52.01   NaN
# 444    26   128    33    49    72    60    67        66.76   NaN
# 447    30   149    37    54    86    69    75        76.73   NaN

# %%
b530.dropna(subset=['grade'], inplace=True)

# %%
X = b530[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6','CLO7']]
y = b530['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logReg = LogisticRegression()
logReg.fit(X_train, y_train)

lr_expected = y_test
lr_predicted = logReg.predict(X_test)
lr_y_proba = logReg.predict_proba(X_test)[:,1]
score = logReg.score(X_test, y_test)
print('Logistic Regression =',score)
train_acc = logReg.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
# Out:
# Logistic Regression = 0.2076923076923077
# The Training Accuracy is 35.824742268041234

# %%
from sklearn.metrics import classification_report
print(classification_report(lr_expected, lr_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00        28
#           A-       0.22      0.69      0.33        32
#            B       0.00      0.00      0.00        30
#           B+       0.22      0.14      0.17        36
#           B-       0.00      0.00      0.00         4
#
#     accuracy                           0.21       130
#    macro avg       0.09      0.17      0.10       130
# weighted avg       0.11      0.21      0.13       130

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC for b530 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC for b530 course = 0.823076923076923
# The Training Accuracy is 99.74226804123711
#               precision    recall  f1-score   support
#
#            A       0.83      0.86      0.84        28
#           A-       0.75      0.84      0.79        32
#            B       0.86      0.83      0.85        30
#           B+       0.85      0.81      0.83        36
#           B-       1.00      0.50      0.67         4
#
#     accuracy                           0.82       130
#    macro avg       0.86      0.77      0.80       130
# weighted avg       0.83      0.82      0.82       130

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))
# Out:
# Cross-Validation Accuracy Scores 0.7461538461538462

# %%
importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in ./.local/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (from xgboost) (2.0.0)
# Requirement already satisfied: scipy in ./.local/lib/python3.9/site-packages (from xgboost) (1.13.1)
# Requirement already satisfied: nvidia-nccl-cu12 in ./.local/lib/python3.9/site-packages (from xgboost) (2.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)

xgb_predicted = xgb.predict(X_test)
xgb_expected = y_test
xgb_y_proba = xgb.predict_proba(X_test)[:,1]
score = xgb.score(X_test, y_test)
print('XGB =',score)
train_acc = xgb.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
# Out:
# XGB = 0.0
# The Training Accuracy is 99.74226804123711

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in ./.local/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.local/lib/python3.9/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in ./.local/lib/python3.9/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.local/lib/python3.9/site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.8.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (38,16))
sns.heatmap(b530.corr(), annot = True)
sns.set(font_scale=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(b530.corr(), annot = True)
#       3 sns.set(font_scale=3)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'A-'

# %% [markdown]
# # b505

# %%
b505.head()
# Out:
#                       STUDENT_IDS   CLO1   CLO2  CLO3  CLO4  CLO5  CLO6  \
# 0                         CLO_MAX  105.0  210.0  70.0  70.0  90.0  45.0
# 1  FA20-INFO-B 505 - 0100 (25067)   89.5  179.4  60.4  60.1  76.3  38.7
# 2  FA20-INFO-B 505 - 0100 (25067)   88.8  185.8  59.2  60.8  76.2  38.6
# 3  FA20-INFO-B 505 - 0100 (25067)   89.9  177.0  60.2  59.2  76.4  39.4
# 4  FA20-INFO-B 505 - 0100 (25067)   90.7  179.9  59.9  60.6  78.9  39.9
#
#     CLO7  CLO8  CLO9  CLO10  Final_grade
# 0  240.0  80.0  70.0   90.0       100.00
# 1  207.0  69.0  58.2   77.3        86.89
# 2  209.6  67.4  61.2   77.2        88.52
# 3  205.2  68.4  61.3   77.6        87.70
# 4  206.4  69.1  60.3   76.8        89.56

# %%
b505_CL01 = b505['CLO1']
b505_CL02 = b505['CLO2']
b505_CL03 = b505['CLO3']
b505_CL04 = b505['CLO4']
b505_CL05 = b505['CLO5']
b505_CL06 = b505['CLO6']
b505_CL07 = b505['CLO7']
b505_CL08 = b505['CLO8']
b505_CL09 = b505['CLO9']
b505_CL10 = b505['CLO10']

# %%
b505_CL01 = b505_CL01.iloc[1:]
above_80_b505_CL01 = (b505_CL01 > 84).sum() / len(b505_CL01) * 100
print(f"{above_80_b505_CL01:.2f}% of students secured above 80% in the b505_CL01.")

b505_CL02 = b505_CL02.iloc[1:]
above_80_b505_CL02 = (b505_CL02 > 168).sum() / len(b505_CL02) * 100
print(f"{above_80_b505_CL02:.2f}% of students secured above 80% in the b505_CL02.")

b505_CL03 = b505_CL03.iloc[1:]
above_80_b505_CL03 = (b505_CL03 > 56).sum() / len(b505_CL03) * 100
print(f"{above_80_b505_CL03:.2f}% of students secured above 80% in the b505_CL03.")

b505_CL04 = b505_CL04.iloc[1:]
above_80_b505_CL04 = (b505_CL04 > 56).sum() / len(b505_CL04) * 100
print(f"{above_80_b505_CL04:.2f}% of students secured above 80% in the b505_CL04.")

b505_CL05 = b505_CL05.iloc[1:]
above_80_b505_CL05 = (b505_CL05 > 72).sum() / len(b505_CL05) * 100
print(f"{above_80_b505_CL05:.2f}% of students secured above 80% in the b505_CL05.")

b505_CL06 = b505_CL06.iloc[1:]
above_80_b505_CL06 = (b505_CL06 > 36).sum() / len(b505_CL06) * 100
print(f"{above_80_b505_CL06:.2f}% of students secured above 80% in the b505_CL06.")

b505_CL07 = b505_CL07.iloc[1:]
above_80_b505_CL07 = (b505_CL07 > 192).sum() / len(b505_CL07) * 100
print(f"{above_80_b505_CL07:.2f}% of students secured above 80% in the b505_CL07.")

b505_CL08 = b505_CL08.iloc[1:]
above_80_b505_CL08 = (b505_CL08 > 64).sum() / len(b505_CL08) * 100
print(f"{above_80_b505_CL08:.2f}% of students secured above 80% in the b505_CL08.")

b505_CL09 = b505_CL09.iloc[1:]
above_80_b505_CL09 = (b505_CL09 > 56).sum() / len(b505_CL09) * 100
print(f"{above_80_b505_CL09:.2f}% of students secured above 80% in the b505_CL09.")

b505_CL10 = b505_CL10.iloc[1:]
above_80_b505_CL10 = (b505_CL10 > 72).sum() / len(b505_CL10) * 100
print(f"{above_80_b505_CL10:.2f}% of students secured above 80% in the b505_CL10.")
# Out:
# 99.46% of students secured above 80% in the b505_CL01.
# 99.64% of students secured above 80% in the b505_CL02.
# 99.64% of students secured above 80% in the b505_CL03.
# 99.46% of students secured above 80% in the b505_CL04.
# 99.64% of students secured above 80% in the b505_CL05.
# 99.46% of students secured above 80% in the b505_CL06.
# 99.82% of students secured above 80% in the b505_CL07.
# 99.46% of students secured above 80% in the b505_CL08.
# 99.64% of students secured above 80% in the b505_CL09.
# 99.09% of students secured above 80% in the b505_CL10.

# %%
plt.hist(b505_CL01, 10)
sns.set(font_scale=1)

# %%
plt.hist(b505_CL02, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   1., 127., 251., 138.,  34.]),
#  array([ 92.4 , 105.09, 117.78, 130.47, 143.16, 155.85, 168.54, 181.23,
#         193.92, 206.61, 219.3 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL03, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   9., 205., 233.,  88.,  16.]),
#  array([31.5 , 35.85, 40.2 , 44.55, 48.9 , 53.25, 57.6 , 61.95, 66.3 ,
#         70.65, 75.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL04, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   2., 149., 244., 124.,  32.]),
#  array([30.  , 34.39, 38.78, 43.17, 47.56, 51.95, 56.34, 60.73, 65.12,
#         69.51, 73.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL05, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,  13., 200., 228., 100.,  10.]),
#  array([40.7 , 46.27, 51.84, 57.41, 62.98, 68.55, 74.12, 79.69, 85.26,
#         90.83, 96.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL06, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,  20., 226., 192.,  99.,  14.]),
#  array([20.8 , 23.55, 26.3 , 29.05, 31.8 , 34.55, 37.3 , 40.05, 42.8 ,
#         45.55, 48.3 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL07, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0., 164., 233., 130.,  24.]),
#  array([109.1 , 123.37, 137.64, 151.91, 166.18, 180.45, 194.72, 208.99,
#         223.26, 237.53, 251.8 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL08, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   6., 186., 248.,  91.,  20.]),
#  array([35.7 , 40.64, 45.58, 50.52, 55.46, 60.4 , 65.34, 70.28, 75.22,
#         80.16, 85.1 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL09, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   1., 168., 265., 101.,  16.]),
#  array([29.1 , 33.66, 38.22, 42.78, 47.34, 51.9 , 56.46, 61.02, 65.58,
#         70.14, 74.7 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(b505_CL10, 10)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,  42., 223., 204.,  72.,  10.]),
#  array([41.2 , 46.87, 52.54, 58.21, 63.88, 69.55, 75.22, 80.89, 86.56,
#         92.23, 97.9 ]),
#  <BarContainer object of 10 artists>)

# %%
b505
# Out:
#                         STUDENT_IDS   CLO1   CLO2  CLO3  CLO4  CLO5  CLO6  \
# 0                           CLO_MAX  105.0  210.0  70.0  70.0  90.0  45.0
# 1    FA20-INFO-B 505 - 0100 (25067)   89.5  179.4  60.4  60.1  76.3  38.7
# 2    FA20-INFO-B 505 - 0100 (25067)   88.8  185.8  59.2  60.8  76.2  38.6
# 3    FA20-INFO-B 505 - 0100 (25067)   89.9  177.0  60.2  59.2  76.4  39.4
# 4    FA20-INFO-B 505 - 0100 (25067)   90.7  179.9  59.9  60.6  78.9  39.9
# ..                              ...    ...    ...   ...   ...   ...   ...
# 548         FA23-IN-INFO-B505-28955   94.3  194.8  64.2  62.9  83.8  40.0
# 549         FA23-IN-INFO-B505-28955   90.2  162.5  55.1  59.8  69.6  35.8
# 550         FA23-IN-INFO-B505-28955   94.9  206.9  70.1  68.1  86.5  45.2
# 551         FA23-IN-INFO-B505-28955   95.6  193.8  67.5  64.8  86.5  42.0
# 552         FA23-IN-INFO-B505-28955  105.9  191.3  72.9  70.2  86.2  40.0
#
#       CLO7  CLO8  CLO9  CLO10  Final_grade
# 0    240.0  80.0  70.0   90.0       100.00
# 1    207.0  69.0  58.2   77.3        86.89
# 2    209.6  67.4  61.2   77.2        88.52
# 3    205.2  68.4  61.3   77.6        87.70
# 4    206.4  69.1  60.3   76.8        89.56
# ..     ...   ...   ...    ...          ...
# 548  231.6  73.4  71.3   89.3        94.00
# 549  200.2  62.6  55.4   71.4        80.62
# 550  212.2  74.7  66.1   92.7        95.08
# 551  217.1  71.8  63.2   82.2        92.00
# 552  225.9  74.2  66.3   89.3        95.54
#
# [553 rows x 12 columns]

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9', 'CLO10']
histb505 = b505[columns].values
plt.hist(histb505.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9', 'CLO10']

barb505 = b505[columns].values
plt.bar(range(len(columns)), barb505.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-505 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('505barcblue.png') 
plt.show()

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b505['grade'] = pd.cut(b505['Final_grade'], bins, labels=labels)

# %%
b505 = b505.drop(['STUDENT_IDS'], axis = 1)
b505 = b505.drop (0, axis = 0)
b505.head()
# Out:
#    CLO1   CLO2  CLO3  CLO4  CLO5  CLO6   CLO7  CLO8  CLO9  CLO10  Final_grade  \
# 1  89.5  179.4  60.4  60.1  76.3  38.7  207.0  69.0  58.2   77.3        86.89
# 2  88.8  185.8  59.2  60.8  76.2  38.6  209.6  67.4  61.2   77.2        88.52
# 3  89.9  177.0  60.2  59.2  76.4  39.4  205.2  68.4  61.3   77.6        87.70
# 4  90.7  179.9  59.9  60.6  78.9  39.9  206.4  69.1  60.3   76.8        89.56
# 5  91.8  185.6  60.8  60.5  76.3  38.9  202.2  68.1  61.7   76.5        88.57
#
#   grade
# 1     B
# 2    B+
# 3    B+
# 4    B+
# 5    B+

# %%
# convert to numerical
b505 = b505.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int',"CLO7":'int',"CLO8":'int',"CLO9":'int',"CLO10":'int'})

# %%
missing_values = b505.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# CLO7           0
# CLO8           0
# CLO9           0
# CLO10          0
# Final_grade    0
# grade          1
# dtype: int64

# %%
b505.dropna(subset=['grade'], inplace=True)

# %%
X = b505[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6','CLO7','CLO8','CLO9','CLO10']]
y = b505['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for b505 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for b505 course = 0.8188405797101449
# The Training Accuracy is 100.0
#               precision    recall  f1-score   support
#
#            A       0.85      0.89      0.87        56
#           A+       1.00      0.17      0.29         6
#           A-       0.77      0.73      0.75        33
#            B       0.93      0.82      0.88        17
#           B+       0.75      0.96      0.84        25
#           B-       0.00      0.00      0.00         1
#
#     accuracy                           0.82       138
#    macro avg       0.72      0.60      0.60       138
# weighted avg       0.82      0.82      0.80       138

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Cross-Validation Accuracy Scores 0.8038461538461539

# %%
plt.figure(figsize = (38,16))
sns.heatmap(b505.corr(), annot = True)
sns.set(font_scale=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(b505.corr(), annot = True)
#       3 sns.set(font_scale=3)
#       4 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B'

# %% [markdown]
# # i501

# %%
i501.head()
# Out:
#                                          STUDENT_IDS   CLO1  CLO2   CLO3  \
# 0                                            CLO_MAX  120.0  90.0  160.0
# 1                            FA20-IN-INFO-I501-27187  105.8  77.6  138.9
# 2                            FA20-IN-INFO-I501-23182   99.6  75.1  129.4
# 3  FA20-IN-INFO-I501-23182 and FA20-IN-INFO-I501-...  107.3  78.0  144.5
# 4  FA20-IN-INFO-I501-23182 and FA20-IN-INFO-I501-...   95.6  71.4  127.6
#
#     CLO4  CLO5   CLO6   CLO7  CLO8  CLO9  CLO10  Final_grade
# 0  150.0  30.0  160.0  110.0  70.0  40.0  150.0       100.00
# 1  131.1  26.9  137.0   98.5  60.1  34.5  129.2        89.99
# 2  124.0  25.0  131.0   91.3  57.8  33.5  123.3        85.07
# 3  133.6  27.1  141.5   98.9  61.3  35.1  130.3        90.44
# 4  123.7  24.4  130.3   87.2  56.3  31.9  118.9        82.55

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
i501['grade'] = pd.cut(i501['Final_grade'], bins, labels=labels)

# %%
#checking for null values
i501.isnull().sum()
# Out:
# STUDENT_IDS     0
# CLO1            0
# CLO2            0
# CLO3            0
# CLO4            0
# CLO5            0
# CLO6            0
# CLO7            0
# CLO8            0
# CLO9            0
# CLO10           0
# Final_grade     0
# grade          39
# dtype: int64

# %%
i501 = i501[i501['grade'].notna()]

# %%
i501 = i501.drop(['STUDENT_IDS'], axis = 1)
i501 = i501.drop (0, axis = 0)
# convert to numerical
i501 = i501.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int',"CLO7":'int',"CLO8":'int',"CLO9":'int',"CLO10":'int'})
i501.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  CLO8  CLO9  CLO10  Final_grade  \
# 1   105    77   138   131    26   137    98    60    34    129        89.99
# 2    99    75   129   124    25   131    91    57    33    123        85.07
# 3   107    78   144   133    27   141    98    61    35    130        90.44
# 4    95    71   127   123    24   130    87    56    31    118        82.55
# 5    93    70   126   120    24   123    87    54    30    115        80.53
#
#   grade
# 1    B+
# 2     B
# 3    A-
# 4    B-
# 5    B-

# %%
i501
# Out:
#      CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  CLO8  CLO9  CLO10  Final_grade  \
# 1     105    77   138   131    26   137    98    60    34    129        89.99
# 2      99    75   129   124    25   131    91    57    33    123        85.07
# 3     107    78   144   133    27   141    98    61    35    130        90.44
# 4      95    71   127   123    24   130    87    56    31    118        82.55
# 5      93    70   126   120    24   123    87    54    30    115        80.53
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...          ...
# 468   107    80   114   143    29   150   112    68    38    161        93.38
# 469   109    82   158   136    28   138   109    70    37    142        93.80
# 470   111    75   128   127    27   154    99    64    37    149        90.30
# 471   113    84   150   151    30   128   104    63    36    140        92.87
# 472   111    87   142   143    27   140   102    74    33    143        93.29
#
#     grade
# 1      B+
# 2       B
# 3      A-
# 4      B-
# 5      B-
# ..    ...
# 468     A
# 469     A
# 470    A-
# 471    A-
# 472     A
#
# [433 rows x 12 columns]

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9', 'CLO10']
histi501 = i501[columns].values
plt.hist(histi501.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9', 'CLO10']

bari501 = i501[columns].values
plt.bar(range(len(columns)), bari501.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('i501 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('i501barcblue.png') 
plt.show()

# %%
X = i501[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6','CLO7','CLO8','CLO9','CLO10']]
y = i501['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for i501 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for i501 course = 0.7614678899082569
# The Training Accuracy is 100.0
#               precision    recall  f1-score   support
#
#            A       0.81      0.93      0.86        27
#           A+       0.00      0.00      0.00         2
#           A-       0.60      0.56      0.58        16
#            B       0.76      0.86      0.81        29
#           B+       0.79      0.62      0.70        24
#           B-       0.82      0.82      0.82        11
#
#     accuracy                           0.76       109
#    macro avg       0.63      0.63      0.63       109
# weighted avg       0.75      0.76      0.75       109

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show() 
sns.set(font_scale=1)
# Out:
# Cross-Validation Accuracy Scores 0.7436363636363637

# %%
plt.figure(figsize = (38,16))
sns.heatmap(i501.corr(), annot = True)
sns.set(font_scale=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(i501.corr(), annot = True)
#       3 sns.set(font_scale=3)
#       4 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B+'

# %% [markdown]
# # b535

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b535['grade'] = pd.cut(b535['Final_grade'], bins, labels=labels)

# %%
b535.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  Final_grade grade
# 1   397   218   159   421   298   174        94.96     A
# 2   363   204   147   396   279   155        87.96    B+
# 3   360   199   147   395   267   159        87.14    B+
# 4   367   204   146   395   270   155        87.93    B+
# 5   392   222   158   414   292   166        94.06     A

# %%
missing_values = b535.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# Final_grade    0
# grade          0
# dtype: int64

# %%
b535.dropna(subset=['grade'], inplace=True)

# %%
print(b535.columns)
# Check if 'STUDENT_IDS' is in the columns
if 'STUDENT_IDS' in b535.columns:
    print("Column 'STUDENT_IDS' exists in DataFrame.")
else:
    print("Column 'STUDENT_IDS' does not exist in DataFrame.")
# Out:
# Index(['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'Final_grade', 'grade'], dtype='object')
# Column 'STUDENT_IDS' does not exist in DataFrame.

# %%
# convert to numerical
b535 = b535.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int'})
b535.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  Final_grade grade
# 1   397   218   159   421   298   174        94.96     A
# 2   363   204   147   396   279   155        87.96    B+
# 3   360   199   147   395   267   159        87.14    B+
# 4   367   204   146   395   270   155        87.93    B+
# 5   392   222   158   414   292   166        94.06     A

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6']
histb535 = b535[columns].values
plt.hist(histb535.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()
plt.savefig('b535.png')

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6']

barb535 = b535[columns].values
plt.bar(range(len(columns)), barb535.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-535 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('b535barcblue.png') 
plt.show()

# %%
X = b535[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6']]
y = b535['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for b535 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for b535 course = 0.74
# The Training Accuracy is 100.0
#               precision    recall  f1-score   support
#
#            A       0.67      0.79      0.72        28
#           A-       0.79      0.62      0.69        42
#            B       0.88      0.78      0.82         9
#           B+       0.73      0.90      0.81        21
#
#     accuracy                           0.74       100
#    macro avg       0.77      0.77      0.76       100
# weighted avg       0.75      0.74      0.74       100

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show() 
sns.set(font_scale=1)
# Out:
# Cross-Validation Accuracy Scores 0.72

# %% [markdown]
# # b518

# %%
b518.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  CLO8  CLO9  Final_grade grade
# 1    83   110   241   210   776    84   517   640   953        86.60     B
# 2    92   116   255   226   798    91   533   661   999        92.65    A-
# 3    89   117   255   227   842    92   542   701  1020        94.23     A
# 4    84   110   239   218   793    86   528   660   967        88.30    B+
# 5    84   111   232   213   778    86   507   644   966        87.39    B+

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b518['grade'] = pd.cut(b518['Final_grade'], bins, labels=labels)

# %%
missing_values = b518.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# CLO7           0
# CLO8           0
# CLO9           0
# Final_grade    0
# grade          8
# dtype: int64

# %%
b518.dropna(subset=['grade'], inplace=True)

# %%
# convert to numerical
b518 = b518.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int',"CLO7":'int',"CLO8":'int',"CLO9":'int'})
b518.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  CLO8  CLO9  Final_grade grade
# 1    83   110   241   210   776    84   517   640   953        86.60     B
# 2    92   116   255   226   798    91   533   661   999        92.65    A-
# 3    89   117   255   227   842    92   542   701  1020        94.23     A
# 4    84   110   239   218   793    86   528   660   967        88.30    B+
# 5    84   111   232   213   778    86   507   644   966        87.39    B+

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9']
histb518 = b518[columns].values
plt.hist(histb518.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7', 'CLO8', 'CLO9']

barb518 = b518[columns].values
plt.bar(range(len(columns)), barb518.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-518 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('b518barcblue.png') 
plt.show()

# %%
X = b518[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6']]
y = b518['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for b518 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for b518 course = 0.6571428571428571
# The Training Accuracy is 100.0
#               precision    recall  f1-score   support
#
#            A       0.67      0.77      0.71        13
#           A+       0.00      0.00      0.00         3
#           A-       0.75      0.77      0.76        31
#            B       0.54      0.59      0.57        22
#           B+       0.59      0.55      0.57        29
#           B-       0.86      0.86      0.86         7
#
#     accuracy                           0.66       105
#    macro avg       0.57      0.59      0.58       105
# weighted avg       0.64      0.66      0.65       105

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show() 
sns.set(font_scale=1)
# Out:
# Cross-Validation Accuracy Scores 0.6254545454545454

# %%
plt.figure(figsize = (38,16))
sns.heatmap(b518.corr(), annot = True)
plt.savefig('heatmap.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [149], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(b518.corr(), annot = True)
#       3 plt.savefig('heatmap.png')
#       4 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B'

# %% [markdown]
# # b581

# %%
b581.head()
# Out:
#                       STUDENT_IDS   CLO1   CLO2   CLO3   CLO4   CLO5  CLO6  \
# 0                         CLO_MAX  110.0  100.0  150.0  270.0  190.0  70.0
# 1  FA20-INFO-B 581 - 0100 (34194)   93.3   82.9  124.6  224.2  164.0  58.0
# 2  FA20-INFO-B 581 - 0100 (34194)   97.3   91.2  133.1  249.3  173.4  63.4
# 3  FA20-INFO-B 581 - 0100 (34194)   98.5   92.0  135.7  247.5  171.8  63.7
# 4  FA20-INFO-B 581 - 0100 (34194)   99.4   89.8  134.4  245.7  167.4  61.1
#
#     CLO7  Final_grade
# 0  310.0       100.00
# 1  262.1        86.73
# 2  274.0        92.69
# 3  289.5        93.48
# 4  279.9        91.64

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b581['grade'] = pd.cut(b581['Final_grade'], bins, labels=labels)
b581 = b581.drop(['STUDENT_IDS'], axis = 1)
b581 = b581.drop (0, axis = 0)
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  Final_grade grade
# 1    93    82   124   224   164    58   262        86.73     B
# 2    97    91   133   249   173    63   274        92.69    A-
# 3    98    92   135   247   171    63   289        93.48     A
# 4    99    89   134   245   167    61   279        91.64    A-
# 5    90    82   124   221   159    59   257        85.74     B

# %%
missing_values = b581.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# CLO7           0
# Final_grade    0
# grade          1
# dtype: int64

# %%
b581.dropna(subset=['grade'], inplace=True)

# %%
# convert to numerical
b581 = b581.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int',"CLO7":'int'})
b581.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  CLO7  Final_grade grade
# 1    93    82   124   224   164    58   262        86.73     B
# 2    97    91   133   249   173    63   274        92.69    A-
# 3    98    92   135   247   171    63   289        93.48     A
# 4    99    89   134   245   167    61   279        91.64    A-
# 5    90    82   124   221   159    59   257        85.74     B

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']
histb581 = b581[columns].values
plt.hist(histb581.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6', 'CLO7']

barb581 = b581[columns].values
plt.bar(range(len(columns)), barb581.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-581 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('b581barcblue.png')
plt.show()

# %%
X = b581[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6']]
y = b581['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for b581 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy of is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for b581 course = 0.7142857142857143
# The Training Accuracy of is 100.0
#               precision    recall  f1-score   support
#
#            A       0.83      0.83      0.83        23
#           A-       0.48      0.55      0.51        22
#            B       1.00      0.91      0.95        11
#           B+       0.73      0.68      0.70        28
#
#     accuracy                           0.71        84
#    macro avg       0.76      0.74      0.75        84
# weighted avg       0.73      0.71      0.72        84

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Cross-Validation Accuracy Scores 0.7652777777777777

# %%
plt.figure(figsize = (38,16))
sns.heatmap(b581.corr(), annot = True)
plt.savefig('heatmap.png')
plt.show()
sns.set(font_scale=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [165], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(b581.corr(), annot = True)
#       3 plt.savefig('heatmap.png')
#       4 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B'

# %% [markdown]
# # b642

# %%
b642.head()
# Out:
#                       STUDENT_IDS   CLO1  CLO2   CLO3   CLO4   CLO5   CLO6  \
# 0                         CLO_MAX  128.0  73.0  178.0  138.0  280.0  238.0
# 1  SP21-INFO-B 642 - 0100 (22922)  114.9  65.6  160.4  122.6  242.9  205.6
# 2  SP21-INFO-B 642 - 0100 (22922)  112.7  65.1  154.9  121.7  247.5  207.1
# 3  SP21-INFO-B 642 - 0100 (22922)  108.7  63.4  157.4  120.3  237.5  207.4
# 4  SP21-INFO-B 642 - 0100 (22922)  119.5  68.6  168.4  128.2  253.6  220.6
#
#    Final_grade
# 0       100.00
# 1        90.56
# 2        89.86
# 3        88.83
# 4        95.33

# %%
bins = [80, 83, 87, 90, 93, 97,100 ]    
labels = ["B-", "B", "B+", "A-",  "A", "A+"]    
# pd.cut(df.Final_grade, bins=bins, labels=labels)
b642['grade'] = pd.cut(b642['Final_grade'], bins, labels=labels)

# %%
missing_values = b642.isnull().sum()
print(missing_values)
# Out:
# CLO1           0
# CLO2           0
# CLO3           0
# CLO4           0
# CLO5           0
# CLO6           0
# Final_grade    0
# grade          6
# dtype: int64

# %%
b642.dropna(subset=['grade'], inplace=True)

# %%
# convert to numerical
b642 = b642.astype({"CLO1":'int', "CLO2":'int',"CLO3":'int',"CLO4":'int',"CLO5":'int',"CLO6":'int'})
b642.head()
# Out:
#    CLO1  CLO2  CLO3  CLO4  CLO5  CLO6  Final_grade grade
# 1   114    65   160   122   242   205        90.56    A-
# 2   112    65   154   121   247   207        89.86    B+
# 3   108    63   157   120   237   207        88.83    B+
# 4   119    68   168   128   253   220        95.33     A
# 5   114    66   157   127   247   209        92.53    A-

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6']
histb642 = b642[columns].values
plt.hist(histb642.flatten(), bins=20, edgecolor='black', color='#B0E0E6')
sns.set(font_scale=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
columns = ['CLO1', 'CLO2', 'CLO3', 'CLO4', 'CLO5', 'CLO6']

barb642 = b642[columns].values
plt.bar(range(len(columns)), barb642.mean(axis=0), edgecolor='black')
plt.xlabel('Class Learning Objectives')
plt.ylabel('Mean Value')
plt.title('B-642 CLO distribution')
plt.xticks(range(len(columns)), columns, rotation=45)
plt.savefig('b642barcblue.png') 
plt.show()

# %%
X = b642[['CLO1','CLO2','CLO3','CLO4','CLO5','CLO6']]
y = b642['grade']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc_predicted = rfc.predict(X_test)
rfc_expected = y_test
rfc_y_proba = rfc.predict_proba(X_test)[:,1]
score = rfc.score(X_test, y_test)
print('RFC score for b642 course =',score)
train_acc = rfc.score(X_train, y_train)
print("The Training Accuracy of is {}".format(train_acc*100))
from sklearn.metrics import classification_report
print(classification_report(rfc_expected, rfc_predicted))
# Out:
# RFC score for b642 course = 0.6567164179104478
# The Training Accuracy of is 100.0
#               precision    recall  f1-score   support
#
#            A       0.68      0.83      0.75        18
#           A+       0.50      0.50      0.50         2
#           A-       0.53      0.50      0.52        16
#            B       0.67      0.44      0.53         9
#           B+       0.65      0.69      0.67        16
#           B-       1.00      0.83      0.91         6
#
#     accuracy                           0.66        67
#    macro avg       0.67      0.63      0.65        67
# weighted avg       0.66      0.66      0.65        67

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
scores = cross_val_score(rfc, X_test, y_test, cv=10)
print('Cross-Validation Accuracy Scores', np.mean(scores))


importances = rfc.feature_importances_
# Sort the feature importance in descending order
sorted_indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
 
plt.title('RF Feature Importance')
plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
plt.tight_layout()
plt.show() 
sns.set(font_scale=1)
# Out:
# Cross-Validation Accuracy Scores 0.5523809523809523

# %%
plt.figure(figsize = (38,16))
sns.heatmap(b518.corr(), annot = True)
plt.savefig('heatmap.png')
plt.show()
sns.set(font_scale=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [198], in <cell line: 2>()
#       1 plt.figure(figsize = (38,16))
# ----> 2 sns.heatmap(b518.corr(), annot = True)
#       3 plt.savefig('heatmap.png')
#       4 plt.show()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'B'
